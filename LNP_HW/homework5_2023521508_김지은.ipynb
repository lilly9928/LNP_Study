# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
fruits = pd.read_table('C:/Users/User/Downloads/MLWF1/fruit_data_with_colors.txt')

# %%
fruits.head()
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
fruits.shape
# Out:
# (59, 7)

# %%
look_up_fruit_name = dict(zip(fruits.fruit_label.unique(),fruits.fruit_name.unique()))

# %%
look_up_fruit_name
# Out:
# {1: 'apple', 2: 'mandarin', 3: 'orange', 4: 'lemon'}

# %%
from matplotlib import cm
x = fruits[['height','width','mass','color_score']]
y = fruits['fruit_label']

x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=0)

# %%
x_train.head()
# Out:
#     height  width  mass  color_score
# 42     7.2    7.2   154         0.82
# 48    10.1    7.3   174         0.72
# 7      4.0    5.8    76         0.81
# 14     7.3    7.6   152         0.69
# 32     7.0    7.2   164         0.80

# %%
cmap = cm.get_cmap('gnuplot')
scatter = pd.plotting.scatter_matrix(x_train,c=y_train,marker='o',s=40,hist_kwds={'bins':50},figsize=(9,9),cmap=cmap)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
import warnings
warnings.filterwarnings("ignore")

knn.score(x_test,y_test)
# Out:
# 0.5333333333333333

# %%
knn.score(x_train,y_train)
# Out:
# 0.7954545454545454

# %%
fruit_prediction = knn.predict(x_test)
look_up_fruit_name[fruit_prediction[0]]
# Out:
# 'orange'
